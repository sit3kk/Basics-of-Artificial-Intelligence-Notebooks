# %% [markdown]
# # Ridge Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn import linear_model
import scipy.stats as stats
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn import model_selection

# %% [markdown]
# Rozważmy następujący zbiór punktów:

# %%
true_fun = lambda X: np.cos(1.5 * np.pi * X)
n_samples=20
x = np.sort(np.random.rand(n_samples))
y = true_fun(x) + np.random.randn(n_samples) * 0.1
x=np.vstack(x)

# %% [markdown]
# # Przykład
# Proszę wykonać regresję (Ridge Regression) na powyższym zbiorze danych

# %%
clf = Ridge(alpha=1.0)
clf.fit(x, y) 

x_plot = np.vstack(np.linspace(0, 1, 20))
plt.plot(x_plot, clf.predict(x_plot), color='blue',linewidth=3)
plt.plot(x, y, 'ok');
plt.show()

# %% [markdown]
# ## Regresja liniowa

# %%
# prepare models
models = []
predicts = []
names=[]
models.append(('LR degree 2', make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()) ))
models.append(('LR degree 20', make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()) ))

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)
    
x_plot = np.vstack(np.linspace(-3, 3, 1000))
plt.plot(x, y, 'ok');
for i in range(len(models)):
    #print(i)
    plt.plot(x_plot, predicts[i],linewidth=3,label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()    
plt.show()
# Out:
# LR degree 2
# LR degree 20

# %% [markdown]
# # Zadanie
# Proszę wykonać
# * regresję dla wielomianów o stopniu **20**
# * regresję (Ridge Regression) dla wielomianów o stopniu **20** oraz
#    * alpha = 1
#    * alpha = 10 000
#    * alpha = 0.0001

# %%
# prepare models
models = []
predicts = []
names = []
models.append(
    (
        "LR degree 2",
        make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression()),
    )
)
models.append(
    (
        "LR degree 20",
        make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression()),
    )
)

x_plot = np.vstack(np.linspace(-3, 3, 1000))
for name, model in models:
    print(name)
    model.fit(x, y)
    predicts.append(model.predict(x_plot))
    names.append(name)

x_plot = np.vstack(np.linspace(-3, 3, 1000))
plt.plot(x, y, "ok")
for i in range(len(models)):
    # print(i)
    plt.plot(x_plot, predicts[i], linewidth=3, label=names[i])
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
plt.legend()
plt.show()

poly_20_degree = make_pipeline(PolynomialFeatures(20), linear_model.LinearRegression())
ridge_20_degree_1 = Ridge(alpha=1)
ridge_20_degree_10 = Ridge(alpha=10000)
ridge_20_degree_01 = Ridge(alpha=0.0001)

poly_20_degree.fit(x, y)
ridge_20_degree_1.fit(x, y)
ridge_20_degree_10.fit(x, y)
ridge_20_degree_01.fit(x, y)

x_plot = np.vstack(np.linspace(0, 1, 20))
plt.plot(x_plot, poly_20_degree.predict(x_plot), color="yellow")
plt.show()

plt.plot(x_plot, ridge_20_degree_1.predict(x_plot), color="red")
plt.plot(x_plot, ridge_20_degree_10.predict(x_plot), color="green")
plt.plot(x_plot, ridge_20_degree_01.predict(x_plot), color="blue")
plt.show()
# Out:
# LR degree 2
# LR degree 20

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr alpha za pomocą komendy **GridSearchCV**.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

degrees = np.arange(1, 11)
alphas = [0.01, 0.1, 1, 10, 100]

grid_search = GridSearchCV(
    make_pipeline(PolynomialFeatures(), StandardScaler(), Ridge()),
    param_grid={"polynomialfeatures__degree": degrees, "ridge__alpha": alphas},
    scoring="neg_mean_absolute_error",
)

grid_search.fit(x, y)

print("Best Degree:", grid_search.best_params_["polynomialfeatures__degree"])
print("Best Alpha:", grid_search.best_params_["ridge__alpha"])
print("Best R-squared:", grid_search.best_score_)
# Out:
# Best Degree: 5
# Best Alpha: 0.01
# Best R-squared: -0.08834348951839907

# %% [markdown]
# # Zdanie
# Dobierz optymalny stopień wielomianu oraz parametr <tt>alpha</tt> za pomocą metody <tt>GridSearchCV</tt> dla danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.
#
# *  policz r_square score.

# %%
import pandas as pd
df_adv = pd.read_csv('https://raw.githubusercontent.com/przem85/bootcamp/master/statistics/Advertising.csv', index_col=0)
X = df_adv[['TV', 'radio','newspaper']]
y = df_adv['sales']
df_adv.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
degrees = np.arange(1, 11)
alphas = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]

grid_search = GridSearchCV(
    make_pipeline(PolynomialFeatures(), StandardScaler(), Ridge()),
    param_grid={"polynomialfeatures__degree": degrees, "ridge__alpha": alphas},
    scoring="neg_mean_absolute_error",
)

grid_search.fit(X, y)

print("Best Degree:", grid_search.best_params_["polynomialfeatures__degree"])
print("Best Alpha:", grid_search.best_params_["ridge__alpha"])
print("Best R-squared:", grid_search.best_score_)
# Out:
# Best Degree: 4
# Best Alpha: 0.001
# Best R-squared: -0.33346790409905946
