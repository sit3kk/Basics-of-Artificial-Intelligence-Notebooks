# %% [markdown]
# # Zadanie
#
# Napisz (od podstaw) algorytm znajdowania minimum metodą gradientową.
# Zaprezentuj jego działanie na przykładzie funkcji $f(x)=x^2$, startując z punktu $x=2$. Zilustruj całą sytuacje oznaczając na wykresie 5 pierwszych iteracji.

# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: x**2

x = np.linspace(-5, 5, 200)
y = f(x)
plt.plot(x, y, '--k', ms=10);


def step_gradient_1d(x_current, learningRate):
    x_gradient = 2*x_current
    new_x = x_current - learning_rate * x_gradient
    
    plt.arrow(x_current, f(x_current), - (learningRate * x_gradient), -(f(x_current)-f(new_x)),
              head_width=0.05, head_length=0.5,ec="red")
        
    return new_x
def gradient_descent_runner_1d(starting_x, learning_rate, num_iterations):
    x = starting_x
    print(x)
    for i in range(num_iterations):
        x = step_gradient_1d(x,learning_rate)
        #print(x)
    return x

x = np.linspace(-5, 5, 200)
y = f(x)
plt.plot(x, y, '--k')

learning_rate = 0.2
initial_x = 2
num_iterations = 5


x_min = gradient_descent_runner_1d(initial_x, learning_rate, num_iterations)

plt.title('Gradient Descent on f(x) = x^2')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()
# Out:
# 2

# %% [markdown]
# # Zadanie
# Wykonaj powyższe zadania dla
#   * learning_rate = 0.001
#   * learning_rate = 0.1
#   * learning_rate = 0.2
#   * learning_rate = 0.5
#   * learning_rate = 0.9
#   * learning_rate = 0.99
#   * learning_rate = 0.999

# %%
learning_rates = [0.001, 0.1, 0.2, 0.5, 0.9, 0.99, 0.999]

for lr in learning_rates:
    plt.figure()
    plt.plot(x, y, '--k')
    gradient_descent_runner_1d(initial_x, lr, num_iterations)
    plt.title(f'Gradient Descent on f(x) = x^2 with learning rate = {lr}')
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.grid(True)
    plt.show()
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2

# %% [markdown]
# # Zadanie 2
#
# Napisz (od podstaw) algorytm znajdowania minimum metodą gradientową.
# Zaprezentuj jego działanie na przykładzie funkcji
#
# $$
# f(x,y)=4*x^2-2x+y^2,
# $$
#
# startując z punktu $(x,y)=(2,2)$. Zilustruj całą sytuacje oznaczając na wykresie kilka pierwszych iteracji.
# Wykonaj obrazek 3D.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

plt.close('all')

fun = lambda x, y: 4*x**2 + y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


X = np.arange(-7, 7, 0.25)
Y = np.arange(-7, 7, 0.25)
X, Y = np.meshgrid(X, Y)
Z = fun(X, Y)


surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0.01, antialiased=True, alpha=0.3)

def step_gradient_2d(x_current, y_current, learningRate):
    x_gradient = 8 * x_current
    y_gradient = 2 * y_current
    
    new_x = x_current - learningRate * x_gradient
    new_y = y_current - learningRate * y_gradient
    
    ax.quiver(x_current, y_current, fun(x_current, y_current),
              -learningRate * x_gradient, -learningRate * y_gradient,
              -(fun(x_current, y_current) - fun(new_x, new_y)),
              color='red')
    
    return [new_x, new_y]

def gradient_descent_runner_2d(starting_x, starting_y, learning_rate, num_iterations):
    x = starting_x
    y = starting_y
    for i in range(num_iterations):
        x, y = step_gradient_2d(x, y, learning_rate)
        if i < 5: 
            ax.scatter(x, y, fun(x, y), color='blue')
    return [x, y]


learning_rate = 0.1
initial_x = 0
initial_y = 5
num_iterations = 10


[x, y] = gradient_descent_runner_2d(initial_x, initial_y, learning_rate, num_iterations)


ax.scatter([initial_x], [initial_y], [fun(initial_x, initial_y)], color='black')

plt.show()

# %% [markdown]
# # Zadanie
# Wykonaj analogiczne zadanie ale z:
#   * initial_x = 5
#   * initial_y = 0
#   * num_iterations = 10

# %%
plt.close('all')

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

learning_rate = 0.1
initial_x = 5
initial_y = 0
num_iterations = 10


[x, y] = gradient_descent_runner_2d(initial_x, initial_y, learning_rate, num_iterations)

ax.scatter([initial_x], [initial_y], [fun(initial_x, initial_y)], color='black')

plt.show()

# %% [markdown]
# # Zadanie
# Wykonaj analogiczne zadanie ale z obrazkiem 2d
#
# $$
# f(x,y)=x^2-2x+y^2,
# $$
#
# oraz
#
# $$
# f(x,y)=4*x^2-2x+y^2,
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

chi2 = lambda x,y: 4*x**2-2*x+y**2

x = np.arange(-10,10,0.02)
y = np.arange(-10,10,0.02)

X,Y= np.meshgrid(x,y)

Z = chi2(X,Y)

plt.figure()
CS = plt.contour(X,Y,Z)

plt.plot([5],[5],"o")

#####################################

def step_gradient_2d(x_current, y_current, learningRate):
    x_gradient = 8*x_current-2
    y_gradient = 2*y_current
    
    new_x = x_current - (learningRate * x_gradient)
    new_y = y_current - (learningRate * y_gradient)
    
    plt.arrow(x_current, y_current, - (learningRate * x_gradient), - (learningRate * y_gradient), head_width=0.05, head_length=0.5,ec="red")
    
    return [new_x, new_y]
def gradient_descent_runner_2d(starting_x, starting_y, learning_rate, num_iterations):
    x = starting_x
    y = starting_y
    for i in range(num_iterations):
        x, y = step_gradient_2d(x, y, learning_rate)
        #print(x, y)
    return [x, y]


learning_rate = 0.1
initial_x = 0 # initial y-intercept guess
initial_y = 5 # initial slope guess
num_iterations = 1000
[x, y] = gradient_descent_runner_2d(initial_x, initial_y, learning_rate, num_iterations)


#####################################
plt.axis('equal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

chi2 = lambda x,y: x**2-2*x+y**2


x = np.arange(-10,10,0.02)
y = np.arange(-10,10,0.02)

X,Y= np.meshgrid(x,y)

Z = chi2(X,Y)

plt.figure()
CS = plt.contour(X,Y,Z)

plt.plot([5],[5],"o")

#####################################

def step_gradient_2d(x_current, y_current, learningRate):
    x_gradient = 8*x_current-2
    y_gradient = 2*y_current
    
    new_x = x_current - (learningRate * x_gradient)
    new_y = y_current - (learningRate * y_gradient)
    
    plt.arrow(x_current, y_current, - (learningRate * x_gradient), - (learningRate * y_gradient), head_width=0.05, head_length=0.5,ec="red")
    
    return [new_x, new_y]
def gradient_descent_runner_2d(starting_x, starting_y, learning_rate, num_iterations):
    x = starting_x
    y = starting_y
    for i in range(num_iterations):
        x, y = step_gradient_2d(x, y, learning_rate)
        #print(x, y)
    return [x, y]


learning_rate = 0.1
initial_x = 0 # initial y-intercept guess
initial_y = 5 # initial slope guess
num_iterations = 1000
[x, y] = gradient_descent_runner_2d(initial_x, initial_y, learning_rate, num_iterations)


#####################################
plt.axis('equal')
plt.show()

# %% [markdown]
# # Zadanie 3

# %% [markdown]
# Napisz (od podstaw) algorytm znajdowania minimum metodą gradientową.
# Zaprezentuj jego działanie na przykładzie funkcji $f(x)=x^2-y^2$, startując z punktu $x=5$ oraz $x=1$. Zilustruj całą sytuacje oznaczając na wykresie 5 pierwszych iteracji.
#
# Wykonaj rysunek:
#
#   * 2D conture plot
#   * 3D
#
# Co się stanie gdy zaczniemy z punktu $x=5$ oraz $x=0$?

# %%
import numpy as np
import matplotlib.pyplot as plt


f = lambda x, y: x**2 - y**2


x = np.linspace(-6, 6, 400)
y = np.linspace(-6, 6, 400)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)


plt.figure()
cp = plt.contour(X, Y, Z, levels=50, cmap='RdBu')
plt.colorbar(cp)
plt.title('Contour plot of $f(x,y) = x^2 - y^2$')
plt.xlabel('x')
plt.ylabel('y')

def step_gradient_2d(x_current, y_current, learningRate):
    x_gradient = 2 * x_current
    y_gradient = -2 * y_current
    
    new_x = x_current - learningRate * x_gradient
    new_y = y_current - learningRate * y_gradient
    
    plt.arrow(x_current, y_current, -learningRate * x_gradient, -learningRate * y_gradient,
              head_width=0.2, head_length=0.2, fc='red', ec='red')
    
    return [new_x, new_y]

def gradient_descent_runner_2d(starting_x, starting_y, learning_rate, num_iterations):
    x = starting_x
    y = starting_y
    for i in range(num_iterations):
        x, y = step_gradient_2d(x, y, learning_rate)
        if i < 5:  
            plt.scatter(x, y, color='blue')
    return [x, y]


learning_rate = 0.1
initial_x = 5
initial_y = 1
num_iterations = 10

plt.scatter(initial_x, initial_y, color='black')
final_x, final_y = gradient_descent_runner_2d(initial_x, initial_y, learning_rate, num_iterations)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

plt.close('all')

fun = lambda x, y: x**2 - y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


X = np.arange(-6, 6, 0.25)
Y = np.arange(-6, 6, 0.25)
X, Y = np.meshgrid(X, Y)
Z = fun(X, Y)

surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0.01, antialiased=True, alpha=0.3)

def step_gradient_2d(x_current, y_current, learningRate):
    x_gradient = 2 * x_current
    y_gradient = -2 * y_current
    
    new_x = x_current - learningRate * x_gradient
    new_y = y_current - learningRate * y_gradient
    
    ax.quiver(x_current, y_current, fun(x_current, y_current),
              -learningRate * x_gradient, -learningRate * y_gradient,
              -(fun(x_current, y_current) - fun(new_x, new_y)),
              color='red')
    
    return [new_x, new_y]

def gradient_descent_runner_2d(starting_x, starting_y, learning_rate, num_iterations):
    x = starting_x
    y = starting_y
    for i in range(num_iterations):
        x, y = step_gradient_2d(x, y, learning_rate)
        if i < 5:  
            ax.scatter(x, y, fun(x, y), color='blue')
    return [x, y]


learning_rate = 0.1
initial_x = 5
initial_y = 1
num_iterations = 10


[x, y] = gradient_descent_runner_2d(initial_x, initial_y, learning_rate, num_iterations)

ax.scatter([initial_x], [initial_y], [fun(initial_x, initial_y)], color='black')

plt.show()
